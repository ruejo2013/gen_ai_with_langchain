# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Using cached transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Collecting filelock (from transformers)
#   Downloading filelock-3.20.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers)
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Collecting numpy>=1.17 (from transformers)
#   Downloading numpy-2.4.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/patrickrue/anaconda3/envs/langchain-gen-ai/lib/python3.11/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/patrickrue/anaconda3/envs/langchain-gen-ai/lib/python3.11/site-packages (from transformers) (6.0.3)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2025.11.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /Users/patrickrue/anaconda3/envs/langchain-gen-ai/lib/python3.11/site-packages (from transformers) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.34.0->transformers)
#   Downloading fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/patrickrue/anaconda3/envs/langchain-gen-ai/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.34.0->transformers)
#   Downloading hf_xet-1.2.0-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/patrickrue/anaconda3/envs/langchain-gen-ai/lib/python3.11/site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/patrickrue/anaconda3/envs/langchain-gen-ai/lib/python3.11/site-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/patrickrue/anaconda3/envs/langchain-gen-ai/lib/python3.11/site-packages (from requests->transformers) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/patrickrue/anaconda3/envs/langchain-gen-ai/lib/python3.11/site-packages (from requests->transformers) (2025.11.12)
# Using cached transformers-4.57.3-py3-none-any.whl (12.0 MB)
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 28.9 MB/s  0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 68.2 MB/s  0:00:00
# Using cached tokenizers-0.22.1-cp39-abi3-macosx_11_0_arm64.whl (2.9 MB)
# Downloading fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Downloading numpy-2.4.0-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 66.0 MB/s  0:00:00
# Downloading regex-2025.11.3-cp311-cp311-macosx_11_0_arm64.whl (288 kB)
# Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading filelock-3.20.1-py3-none-any.whl (16 kB)
# Installing collected packages: tqdm, safetensors, regex, numpy, hf-xet, fsspec, filelock, huggingface-hub, tokenizers, transformers
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [transformers]  9/10 [transformers]
# Successfully installed filelock-3.20.1 fsspec-2025.12.0 hf-xet-1.2.0 huggingface-hub-0.36.0 numpy-2.4.0 regex-2025.11.3 safetensors-0.7.0 tokenizers-0.22.1 tqdm-4.67.1 transformers-4.57.3

# %%
from transformers import AutoTokenizer

# Load a pre-trained tokenizer
model_name = "meta-llama/Meta-Llama-3-8B"  # deepseek-ai/DeepSeek-V2"
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# Tokenize a text
text = "The quick brown fox jumps over the lazy dog!"

encoded_text = tokenizer(text)

# Access the tokenized IDs
print(tokenizer.decode(encoded_text["input_ids"]))

print(encoded_text["input_ids"])
print(", ".join([tokenizer.decode(t) for t in encoded_text["input_ids"]]))
# Out:
# [CLS] the quick brown fox jumps over the lazy dog! [SEP]
# [101, 1996, 4248, 2829, 4419, 14523, 2058, 1996, 13971, 3899, 999, 102]
# [CLS], the, quick, brown, fox, jumps, over, the, lazy, dog, !, [SEP]
